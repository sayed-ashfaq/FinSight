# %%
print("Hi")
# Out:
# Hi

# %%
import pandas as pd
import sys
import os

# 1. Add backend directory to python path to import our parser
sys.path.append(os.path.abspath('..'))

from services.pdf_parser import parse_kotak_statement

# 2. Parse the unlocked test statement
pdf_path = "../testing_data/Kotak_bankStatement_unlocked.pdf"
transactions = parse_kotak_statement(pdf_path, password=None)

print(f"Successfully extracted {len(transactions)} transactions!")

# 3. Load into Pandas for analysis
df = pd.DataFrame(transactions)

# Convert strings to datetime for easier time-based filtering
df['date'] = pd.to_datetime(df['date'])

# View the latest data
display(df.head(10))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       2 import sys
#       3 import os
#
# ModuleNotFoundError: No module named 'pandas'
